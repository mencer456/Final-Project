# %% [markdown]
# # Metric: Public Art

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

public_art_data = pd.read_csv("public-art.csv", index_col="id")

# %%
public_art_data.sample(10)
# Out:
#                   name                                            title  \
# id
# 515196271   WM00017000               Sacrifice (World War I Honor Roll)
# 360491421   PA00095000                            Pittsburgh Variations
# 603636456   PA00207000                                         Untitled
# 957789229   PA00084000                            Fire Station 27 Mural
# 1557991689  WM00055000  World War II Honor Roll (Spring Hill-City View)
# 1602589575  PA00099000                                      Mountaintop
# 1139976437         163                                  Manimal Friends
# 1002836340  WM00075000                        Duquesne Incline Monument
# 812728309         1001                            Oakwood Road Monument
# 2032091917         129                      Middle East Memorial Plaque
#
#                     artist_name                     art_type  \
# id
# 515196271   Allen George Newman                War Memorials
# ...

# %% [markdown]
# ### Total number of public art pieces

# %%
len(public_art_data)
# Out:
# 198

# %% [markdown]
# # By Neighborhood

# %% [markdown]
# ### Finding number of public art pieces per neighborhood:

# %%
neighborhoods = public_art_data['neighborhood'].value_counts()
neighborhoods
# Out:
# Central Business District    27
# Squirrel Hill South          22
# Allegheny Center             18
# South Side Flats             10
# Highland Park                10
# North Shore                   7
# Shadyside                     6
# Lower Lawrenceville           5
# Brighton Heights              5
# Beechview                     5
# Central Oakland               5
# Hazelwood                     4
# Spring Hill-City View         4
# Point Breeze                  3
# South Side Slopes             3
# Carrick                       3
# Duquesne Heights              3
# Greenfield                    3
# Beltzhoover                   3
# Regent Square                 2
# East Allegheny                2
# Allentown                     2
# Strip District                2
# Spring Garden                 2
# Garfield                      2
# Lincoln-Lemington-Belmar      2
# Elliott                       2
# Upper Hill                    2
# West End                      2
# ...

# %% [markdown]
# ### Visualizing data:

# %%
neighborhoods.plot.bar(figsize=(20, 20))

# %% [markdown]
# # Squirrel Hill South

# %% [markdown]
# ### Look only at Squirrel Hill South

# %%
mask=public_art_data['neighborhood']=='Squirrel Hill South'
shs = public_art_data[mask]
shs
# Out:
#                   name                                              title  \
# id
# 2095627492         160                         Residents of Schenley Park
# 1980433881         161                                              Caves
# 1128072672         172                Grand Army of the Republic Memorial
# 1288339436         173  National Woman's Relief Corps Memorial: Annie ...
# 1089115252         174  National Woman's Relief Corps Memorial: Flo Ja...
# 355302219   PA00001000                                            Neptune
# 1797001777  PA00008000                             Edward Manning Bigelow
# 680343518   PA00010000                                           Panthers
# 772547760   PA00021000                                       Robert Burns
# 1605962003  PA00042000                              Westinghouse Memorial
# 2029617217  PA00047000                                  Drinking Fountain
# 1395398096  PA00060000                               Christopher Columbus
# ...

# %% [markdown]
# ### Different types of art in Squirrel Hill South

# %%
shs['art_type'].value_counts()
# Out:
# Individual and Historic Monuments    11
# Historic Art                          4
# War Memorials                         4
# Modern and Contemporary Art           3
# Name: art_type, dtype: int64

# %% [markdown]
# # Metric Rating

# %%
rate=pd.DataFrame(neighborhoods)
highest=rate.max()
rate["Rating"]=((rate['neighborhood']/27)*10)
rate['Rating'].plot.bar(figsize=(20,5))

# %% [markdown]
# # Conclusion/Analysis

# %% [markdown]
# I was surprised by how many public art pieces there were in Pittsburgh. I also do not know much about Pittsburgh's neighborhoods, so it was interesting to discover what kinds of art are there and which neighborhoods had the most. Using my dataset, I counted the number of public art pieces in each neighborhood, and the Central Business District had the most, followed by Squirrel Hill South and Allegheny Center. Since Squirrel Hill South seemed to be the best in traffic signs and playgrounds and it was nearly the best in my data, the group predicted that Squirrel Hill South was the best overall neighborhood. So out of curiosity, I took only the Squirrel Hill art pieces and sorted them by type to find out what kinds of art are in Squirrel Hill South. Then, under Metric Rating, I converted the number of art pieces each neighborhood had to a rating from 1-10. These ratings are combined with the other ratings from traffic signs and playgrounds to determine the best overall neighborhood: Squirrel Hill South.
